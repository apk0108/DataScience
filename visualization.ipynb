# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0:1]
# Out:
#    Rank  Major_code                  Major   Total     Men  Women  \
# 0     1        2419  PETROLEUM ENGINEERING  2339.0  2057.0  282.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
#
# [1 rows x 21 columns]

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads["Rank"].value_counts()

# %%
raw_data_count.describe()
# Out:
# count    173.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: Rank, dtype: float64

# %%
recent_grads = recent_grads.dropna()

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %%
cleaned_data_count = recent_grads

# %%
raw_data_count.describe()
# Out:
# count    173.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: Rank, dtype: float64

# %%
cleaned_data_count.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %%
cleaned_data_count.plot(x="Sample_size", y="Median", kind="scatter", title="Median vs. Sample Size")

# %%
cleaned_data_count.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Unemploymentrate vs. Sample Size")

# %%
cleaned_data_count.plot(x="Full_time", y="Median", kind="scatter", title="Median vs. FUll time")

# %%
cleaned_data_count.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter", title="Unemploymentrate vs. Share Women")

# %%
cleaned_data_count.plot(x="Men", y="Median", kind="scatter", title="Median vs. Men")

# %%
cleaned_data_count.plot(x="Women", y="Median", kind="scatter", title="Median vs. Women")

# %%
cleaned_data_count["Sample_size"].hist(bins=25, range=(0,1000))

# %%
cleaned_data_count["Median"].hist(bins=15, range=(0, 80000))

# %%
cleaned_data_count["Median"].hist(bins=15, range=(0, 90000))

# %%
cleaned_data_count["Employed"].hist(bins=15, range=(0, 90000))

# %%
cleaned_data_count["Full_time"].hist(bins=30, range=(0, 300000))

# %%
cleaned_data_count["ShareWomen"].hist(bins=10, range=(0, 1))

# %%
cleaned_data_count["Unemployment_rate"].hist(bins=10, range=(0, 0.15))

# %%
cleaned_data_count["Men"].hist(bins=20, range=(0, 200000))

# %%
cleaned_data_count["Women"].hist(bins=20, range=(0, 200000))

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(cleaned_data_count[["Sample_size", "Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbee19ec9e8>,
# ...
#       dtype=object)

# %%
scatter_matrix(cleaned_data_count[["Sample_size", "Median", "Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbee12a06d8>,
# ...
#       dtype=object)

# %%
recent_grads[0:10]["ShareWomen"].plot.bar(x="Major", y="Share Women")

# %%
recent_grads[-10:].plot.bar(x="Major", y="ShareWomen")

# %%
recent_grads[0:10].plot.bar(x="Major", y="Unemployment_rate")

# %%
recent_grads[-10:].plot.bar(x="Major", y="Unemployment_rate")

# %%
women = list(cleaned_data_count["Women"])
men = list(cleaned_data_count["Men"])
index = list(cleaned_data_count.Major_category.unique())
comparison = pd.DataFrame({'women': women,
                   'men': men}, index=index)

ax = comparison.plot.bar(rot=0)
# Out:
# ValueErrorTraceback (most recent call last)
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4637         blocks = form_blocks(arrays, names, axes)
# -> 4638         mgr = BlockManager(blocks, axes)
#    4639         mgr._consolidate_inplace()
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    3032         if do_integrity_check:
# -> 3033             self._verify_integrity()
#    3034
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/internals.py in _verify_integrity(self)
#    3243             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3244                 construction_error(tot_items, block.shape[1:], self.axes)
#    3245         if len(self.items) != tot_items:
#
# ...

# %%
    
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)

# %%
#test= list(cleaned_data_count.Major_category.unique())
#print(test)

#test2 = list(cleaned_data_count["Women"])
#test2.describe()
#print(test2)

##test3 = list(cleaned_data_count.Major_category.unique())
##print(test3)



Idee: Frequency table mit Men und Anzahl der jeweiligen Major category und einmal mit Women und category

# %%
scatter_matrix(cleaned_data_count[["Median", "Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbee0c8fb00>,
# ...
#       dtype=object)

# %%
cleaned_data_count.plot.hexbin(x='Men', y='Employed', gridsize=15)

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x='a', y='b', gridsize=25)
